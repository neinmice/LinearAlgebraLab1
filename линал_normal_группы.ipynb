# %%
import random
from sympy.combinatorics import Permutation, PermutationGroup, SymmetricGroup
from math import gcd
from itertools import combinations

def subgroups_of_Sm() -> dict:
    # вычисление параметров
    N = 504998
    m = 7
    mod5 = 3
    p, s, r, t = 23, 17, 45, 12
    n1 = N % 6
    n2 = (N + 1) % 6
    n3 = (N + 2) % 6
    # создаем симметрическую группу S_m
    S_m = SymmetricGroup(7)
    
    # получаем только самые значимые подгруппы
    all_subgroups = []
    
    # тривиальная подгруппа {e}
    trivial = PermutationGroup(Permutation(list(range(m))))
    all_subgroups.append(trivial)
    
    # стабилизаторы одной точки (изоморфны S6)
    for i in range(m):
        stab = S_m.stabilizer(i)
        if stab not in all_subgroups:
            all_subgroups.append(stab)
    
    # циклические подгруппы различных порядков
    # порядки элементов в S₇: 1, 2, 3, 4, 5, 6, 7, 10, 12
    # берем по одному представителю каждого порядка (кроме 1 - тривиальный)
    orders_found = set([1])
    
    # находим элементы разных порядков
    for order in [2, 3, 4, 5, 6, 7, 10, 12]:
        for perm in S_m.elements:
            if perm.order() == order and order not in orders_found:
                cyclic_sub = PermutationGroup(perm)
                all_subgroups.append(cyclic_sub)
                orders_found.add(order)
                break
    
    # подгруппа, порожденная транспозицией (минимальная нетривиальная)
    transposition = Permutation(0, 1)
    trans_sub = PermutationGroup(transposition)
    if trans_sub not in all_subgroups:
        all_subgroups.append(trans_sub)
    
    # подгруппа, порожденная полным циклом (порядка 7)
    full_cycle = Permutation(*range(m))
    cycle_sub = PermutationGroup(full_cycle)
    if cycle_sub not in all_subgroups:
        all_subgroups.append(cycle_sub)
    
    # убираем дубликаты и сортируем
    unique_subgroups = []
    seen_orders_elements = set()
    
    for subgroup in all_subgroups:
        # создаем уникальный идентификатор
        identifier = tuple(sorted(str(p) for p in subgroup.elements))
        if identifier not in seen_orders_elements:
            seen_orders_elements.add(identifier)
            unique_subgroups.append(subgroup)
    
    # сортируем по порядку (от меньшего к большему)
    unique_subgroups.sort(key=lambda x: x.order())
    
    # случайная подгруппа
    random_subgroup = random.choice(unique_subgroups)
    
    # выбранная подгруппа для анализа смежных классов
    subgroup_index = N % len(unique_subgroups)
    selected_subgroup = unique_subgroups[subgroup_index]
    
    # строим смежные классы
    group_elements = list(S_m.generate())
    
    left_cosets_dict = {}
    for g in group_elements:
        coset = set(g * h for h in selected_subgroup.elements)
        if not any(coset == existing_coset for existing_coset in left_cosets_dict.values()):
            left_cosets_dict[g] = coset
    
    right_cosets_dict = {}
    for g in group_elements:
        coset = set(h * g for h in selected_subgroup.elements)
        if not any(coset == existing_coset for existing_coset in right_cosets_dict.values()):
            right_cosets_dict[g] = coset
    
    left_cosets = list(left_cosets_dict.values())
    right_cosets = list(right_cosets_dict.values())
    
    index = len(left_cosets)
    is_normal = (left_cosets == right_cosets)
    
    return {
        'total_subgroups': len(unique_subgroups),
        'random_subgroup': {
            'order': random_subgroup.order(),
            'elements': [str(perm) for perm in random_subgroup.elements]
        },
        'selected_subgroup': {
            'index_in_list': subgroup_index,
            'order': selected_subgroup.order(),
            'elements': [str(perm) for perm in selected_subgroup.elements]
        },
        'coset_analysis': {
            'index': index,
            'is_normal': is_normal,
            'left_cosets_count': len(left_cosets),
            'right_cosets_count': len(right_cosets)
        }
    }

# %%
def element_powers_in_Sm() -> dict:
    '''
    порядки элементов g^n1, g^n2, g^n3 и порядки циклических подгрупп
    '''
    N = 504998
    m = 4 + (N % 5)
    n1 = N % 6
    n2 = (N + 1) % 6
    n3 = (N + 2) % 6
    
    S_m = SymmetricGroup(7)
    elements = list(S_m.generate())
    
    g = elements[N % len(elements)]
    
    def element_order(perm):
        return perm.order()
    
    g_n1 = g ** n1 if n1 > 0 else S_m.identity
    g_n2 = g ** n2 if n2 > 0 else S_m.identity
    g_n3 = g ** n3 if n3 > 0 else S_m.identity
    
    return {
        'g': str(g),
        'g_order': element_order(g),
        'g_n1': {
            'element': str(g_n1),
            'order': element_order(g_n1),
            'subgroup_order': element_order(g_n1)
        },
        'g_n2': {
            'element': str(g_n2),
            'order': element_order(g_n2),
            'subgroup_order': element_order(g_n2)
        },
        'g_n3': {
            'element': str(g_n3),
            'order': element_order(g_n3),
            'subgroup_order': element_order(g_n3)
        }
    }

# %%
def solve_sigma_power_eq() -> dict:
    '''
    все решения уравнения sigma^n = (1 2 3 ... m-1)
    '''
    N = 504998
    m = 4 + (N % 5)          # m = 7
    n = 2 + (N % 10)         # n = 10
    
    # создаем цикл (1 2 3 4 5 6) в S7
    # последний элемент 7 остается неподвижным
    target_cycle = list(range(1, m))  # [1, 2, 3, 4, 5, 6]
    target = Permutation(*target_cycle)
    
    # Группа S7
    S_m = SymmetricGroup(m)  # m = 7
    
    solutions = []
    # получаем все эл-ты группы
    for perm in S_m.elements:
        try:
            if perm**n == target:
                solutions.append(perm)
        except:
            continue
    
    random_solutions = random.sample(solutions, min(3, len(solutions))) if solutions else []
    
    return {
        'equation': f'sigma^{n} = {target}',
        'total_solutions': len(solutions),
        'random_solutions': [str(sol) for sol in random_solutions],
    }

# %%
def elements_of_order_k_in_cyclic_group() -> dict:
    '''
    элементы g такие что g^k = e и элементы порядка k в циклической группе
    '''
    N = 504998
    m = 4 + (N % 5)
    k = 1 + (N % 7)
    
    elements_gk_e = []
    elements_order_k = []
    
    for i in range(m):
        if (i * k) % m == 0:
            elements_gk_e.append(i)
        if gcd(i, m) == 1 and pow(i, k, m) == 1:
            if all(pow(i, d, m) != 1 for d in range(1, k) if k % d == 0):
                elements_order_k.append(i)
    
    return {
        'group_order': m,
        'k': k,
        'elements_gk_e': elements_gk_e,
        'elements_order_k': elements_order_k
    }

# %%
def subgroups_of_Zm_star() -> list:
    '''
    подгруппы мультипликативной группы Zm*
    '''
    N = 504998
    m = 4 + (N % 5)
    
    def get_Zm_star(m):
        return [i for i in range(1, m) if gcd(i, m) == 1]
    
    def is_subgroup(elements, group):
        if not elements:
            return False
        for a in elements:
            for b in elements:
                if (a * b) % m not in elements:
                    return False
            if pow(a, -1, m) not in elements:
                return False
        return True
    
    Zm_star = get_Zm_star(m)
    all_subsets = []
    
    for r in range(1, len(Zm_star) + 1):
        for subset in combinations(Zm_star, r):
            if is_subgroup(subset, Zm_star):
                all_subsets.append(sorted(subset))
    
    return sorted(all_subsets, key=len)

# %%
def order_of_sr() -> int:
    '''
    порядок элемента s^r в Zp*
    '''
    p, s, r = 23, 17, 45
    s_r = pow(s, r, p)
    order = 1
    current = s_r
    while current != 1:
        current = (current * s_r) % p
        order += 1
    
    return order

# %%
def order_and_primitivity_of_t() -> dict:
    '''
    порядок элемента t + проверить, является ли он образующим
    '''
    N = 504998
    #элемент является примитивным корнем, если его порядок равен p-1
    p, t = 23, 12
    order = 1
    current = t
    while current != 1:
        current = (current * t) % p
        order += 1
    
    is_primitive = order == p - 1
    
    return {
        't': t,
        'p': p,
        'order': order,
        'is_primitive': is_primitive
    }

# %%
def generators_of_Zm_star() -> list:
    '''
    примитивные корни циклической группы Zm*
    '''
    N = 504998
    m = 4 + (N % 5)
    
    def is_primitive_root(a, m):
        if gcd(a, m) != 1:
            return False
        order = 1
        current = a
        while current != 1:
            current = (current * a) % m
            order += 1
        return order == len([i for i in range(1, m) if gcd(i, m) == 1])
    
    generators = []
    for a in range(1, m):
        if gcd(a, m) == 1 and is_primitive_root(a, m):
            generators.append(a)
    
    return generators

# %%
def cyclic_subgroup_in_Zm_additive() -> dict:
    ''' 
    нахождение циклич подгруппы, порождённой элементом t mod m
    '''
    #подгруппа состоит из всех кратных t по модулю m, генераторы - элементы, взаимно простые с порядком подгруппы
    
    N = 504998
    m = 4 + (N % 5)
    t = 12
    
    t_mod = t % m
    subgroup = set()
    current = 0
    for i in range(m):
        current = (current + t_mod) % m
        subgroup.add(current)
        if current == 0:
            break
    
    subgroup = sorted(subgroup)
    order = len(subgroup)
    
    generators = []
    for elem in subgroup:
        if elem != 0:
            sub_subgroup = set()
            current_sub = 0
            for i in range(m):
                current_sub = (current_sub + elem) % m
                sub_subgroup.add(current_sub)
                if current_sub == 0:
                    break
            if len(sub_subgroup) == order:
                generators.append(elem)
    
    return {
        't': t,
        't_mod_m': t_mod,
        'subgroup': subgroup,
        'order': order,
        'generators': generators
    }

# %%
def isomorphism_of_cyclic_subgroup_Zm_star() -> dict:
    '''
    циклическая подгруппа в Zm* и её изоморфизм с подгруппой в Sd
    '''
    N = 504998
    m = 4 + (N % 5)
    t = 12
    t_mod = t % m
    
    subgroup = set()
    current = 1
    for i in range(m):
        current = (current * t_mod) % m
        subgroup.add(current)
        if current == 1:
            break
    
    subgroup = sorted(subgroup)
    d = len(subgroup)
    
    S_d = SymmetricGroup(7)
    cyclic_subgroup_Sd = None
    
    for perm in S_d.generate():
        if perm.order() == d:
            cyclic_subgroup = PermutationGroup(perm)
            if cyclic_subgroup.order() == d:
                cyclic_subgroup_Sd = cyclic_subgroup
                break
    
    return {
        'subgroup_Zm*': subgroup,
        'order': d,
        'isomorphic_Sd_subgroup': str(cyclic_subgroup_Sd) if cyclic_subgroup_Sd else "Не найдена",
        'generator_Sd': str(cyclic_subgroup_Sd.generators[0]) if cyclic_subgroup_Sd else None
    }

# %%
# задание 1:
subgroups_of_Sm()
# Out:
# {'total_subgroups': 18,
#  'random_subgroup': {'order': 10,
#   'elements': ['(6)',
#    '(0 2 5 4 6)(1 3)',
#    '(0 4 2 6 5)(1 3)',
#    '(0 5 6 2 4)',
#    '(0 6 4 5 2)',
#    '(6)(1 3)',
#    '(0 2 5 4 6)',
#    '(0 4 2 6 5)',
#    '(0 5 6 2 4)(1 3)',
#    '(0 6 4 5 2)(1 3)']},
#  'selected_subgroup': {'index_in_list': 8,
#   'order': 7,
#   'elements': ['(6)',
#    '(0 1 2 3 4 5 6)',
#    '(0 2 4 6 1 3 5)',
#    '(0 3 6 2 5 1 4)',
#    '(0 4 1 5 2 6 3)',
#    '(0 5 3 1 6 4 2)',
#    '(0 6 5 4 3 2 1)']},
#  'coset_analysis': {'index': 720,
#   'is_normal': False,
#   'left_cosets_count': 720,
#   'right_cosets_count': 720}}

# %% [markdown]
# ### ВАЖНОЕ ПРИМЕЧАНИЕ К ПЕРВОМУ ЗАДАНИЮ
# #### я мучался с поиском ВСЕХ подгрупп около пяти часов и сейчас я полностью уверен, что это невозможно на практике
# #### по крайней мере при моих текущих вычислительных мощностях
# #### так что будем рассматривать только некоторые известные подгруппы

# %%
# задача 2:
element_powers_in_Sm()
# Out:
# {'g': '(6)(0 4 2)(1 5 3)',
#  'g_order': 3,
#  'g_n1': {'element': '(6)(0 2 4)(1 3 5)', 'order': 3, 'subgroup_order': 3},
#  'g_n2': {'element': '(6)', 'order': 1, 'subgroup_order': 1},
#  'g_n3': {'element': '(6)(0 4 2)(1 5 3)', 'order': 3, 'subgroup_order': 3}}

# %%
# задача 3:
solve_sigma_power_eq()
# Out:
# {'equation': 'sigma^10 = (1 2 3 4 5 6)',
#  'total_solutions': 0,
#  'random_solutions': []}

# %%
# задача 4:
elements_of_order_k_in_cyclic_group()
# Out:
# {'group_order': 7, 'k': 5, 'elements_gk_e': [0], 'elements_order_k': []}

# %%
# задача 5:
subgroups_of_Zm_star()
# Out:
# [[1], [1, 6], [1, 2, 4], [1, 2, 3, 4, 5, 6]]

# %%
# задача 7:
order_and_primitivity_of_t()
# Out:
# {'t': 12, 'p': 23, 'order': 11, 'is_primitive': False}

# %%
# задача 8:
generators_of_Zm_star()
# Out:
# [3, 5]

# %%
# задача 6:
order_of_sr()
# Out:
# 22

# %%
# задача 9:
cyclic_subgroup_in_Zm_additive()
# Out:
# {'t': 12,
#  't_mod_m': 5,
#  'subgroup': [0, 1, 2, 3, 4, 5, 6],
#  'order': 7,
#  'generators': [1, 2, 3, 4, 5, 6]}

# %%
# задача 10:
isomorphism_of_cyclic_subgroup_Zm_star()
# Out:
# {'subgroup_Zm*': [1, 2, 3, 4, 5, 6],
#  'order': 6,
#  'isomorphic_Sd_subgroup': 'PermutationGroup([\n    (6)(0 1 2 4 5 3)])',
#  'generator_Sd': '(6)(0 1 2 4 5 3)'}
